# %%
# %pip install -q youtube-transcript-api langchain-community faiss-cpu tiktoken python-dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_ollama import OllamaEmbeddings, ChatOllama
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate
from urllib.parse import urlparse, parse_qs

# %%
def extract_youtube_id(url):
    parsed_url = urlparse(url)
    query_params = parse_qs(parsed_url.query)
    video_id = query_params.get('v', [None])[0]
    return video_id

url = "https://www.youtube.com/watch?v=Mi0QycA81go"
video_id = extract_youtube_id(url)

try:
    transcript_list = YouTubeTranscriptApi.get_transcript(video_id, languages=['en', 'hi'])
    
    transcript = " ".join(chunk['text'] for chunk in transcript_list)
    print(transcript)
    
except TranscriptsDisabled: 
    print("Transcripts are disabled for this video.")

# %%
transcript_list
# Out:
# [{'text': 'Hi everyone and welcome to a new video.',
#   'start': 0.0,
#   'duration': 4.72},
#  {'text': 'This one is around trading arbitragees',
#   'start': 2.399,
#   'duration': 4.4},
#  {'text': 'in sports book. Um that exists for',
#   'start': 4.72,
#   'duration': 5.12},
#  {'text': 'markets like IPL trading. Um basically',
#   'start': 6.799,
#   'duration': 6.8},
#  {'text': "it's not closer to a MPL or a dream 11.",
#   'start': 9.84,
#   'duration': 5.919},
#  {'text': 'Those are some markets to trade on you',
#   'start': 13.599,
#   'duration': 5.241},
#  {'text': 'know sports opinions in India.',
#   'start': 15.759,
#   'duration': 5.921},
#  {'text': 'Um this is not that um there are other',
#   'start': 18.84,
#   'duration': 5.4},
#  {'text': 'markets that exist where people can',
#   'start': 21.68,
#   'duration': 4.4},
#  {'text': 'trade on the final outcome of the match.',
#   'start': 24.24,
#   'duration': 3.84},
#  {'text': 'Is the match going to win? Is Kolkata',
#   'start': 26.08,
#   'duration': 3.279},
#  {'text': 'going to win? Is Kolkata going to lose?',
#   'start': 28.08,
#   'duration': 3.76},
#  {'text': 'Um when you do that uh you are taking',
#   'start': 29.359,
#   'duration': 4.321},
#  {'text': 'some risk. If you say Kolkata is going',
#   'start': 31.84,
#   'duration': 3.36},
#  {'text': 'to win and Kolkata loses, you lose all',
#   'start': 33.68,
#   'duration': 2.96},
#  {'text': 'of your money. You could bet 100 rupees,',
#   'start': 35.2,
#   'duration': 4.24},
#  {'text': 'a 1,000 rupees or a lakh. Um but is',
#   'start': 36.64,
#   'duration': 4.48},
#  {'text': 'there a way to make risk-free money from',
#   'start': 39.44,
#   'duration': 4.0},
#  {'text': 'these markets? Um you might say, "No,',
#   'start': 41.12,
#   'duration': 4.4},
#  {'text': 'that sounds too good to be true." Um or',
#   'start': 43.44,
#   'duration': 4.4},
#  {'text': 'that sounds like a fatty scheme. Um but',
#   'start': 45.52,
#   'duration': 4.0},
#  {'text': "if you heard of HFTs, that's", 'start': 47.84, 'duration': 2.719},
#  {'text': "traditionally what they've been doing",
#   'start': 49.52,
#   'duration': 3.039},
#  {'text': 'for years. Um they are squeezing out',
#   'start': 50.559,
#   'duration': 4.64},
#  {'text': 'inefficiencies from markets without',
#   'start': 52.559,
#   'duration': 3.921},
#  {'text': 'taking any risk themselves. There is',
#   'start': 55.199,
#   'duration': 2.561},
#  {'text': "some level of risk which I'll share here",
#   'start': 56.48,
#   'duration': 3.44},
#  {'text': "as well. uh but most of the times it's",
#   'start': 57.76,
#   'duration': 4.959},
#  {'text': "riskfree profit. Uh it's not a lot of",
#   'start': 59.92,
#   'duration': 4.559},
#  {'text': 'profit. So you have to rinse and repeat',
#   'start': 62.719,
#   'duration': 3.361},
#  {'text': 'it again and again to actually make',
#   'start': 64.479,
#   'duration': 3.201},
#  {'text': 'something substantial but it is',
#   'start': 66.08,
#   'duration': 4.079},
#  {'text': "risk-free. We'll talk through what are",
#   'start': 67.68,
#   'duration': 4.479},
#  {'text': 'traditional sports books, how do how',
#   'start': 70.159,
#   'duration': 3.601},
#  {'text': 'does betting work or how did it used to',
#   'start': 72.159,
#   'duration': 3.521},
#  {'text': 'work a few years ago. How does betting',
#   'start': 73.76,
#   'duration': 4.48},
#  {'text': 'work today? Can you actually squeeze out',
#   'start': 75.68,
#   'duration': 4.72},
#  {'text': 'markets uh inefficiencies from these',
#   'start': 78.24,
#   'duration': 3.68},
#  {'text': 'markets? Can you actually make some',
#   'start': 80.4,
#   'duration': 3.28},
#  {'text': "money uh doing it? I'll show you the",
#   'start': 81.92,
#   'duration': 3.44},
#  {'text': 'experiment that I ran and I was able to',
#   'start': 83.68,
#   'duration': 4.079},
#  {'text': 'make a grand total of amount I will',
#   'start': 85.36,
#   'duration': 4.799},
#  {'text': "share eventually. Um and then we'll code",
#   'start': 87.759,
#   'duration': 3.961},
#  {'text': 'the whole thing because the way I have',
#   'start': 90.159,
#   'duration': 4.721},
#  {'text': 'traded these inefficiencies until now is',
#   'start': 91.72,
#   'duration': 5.0},
#  {'text': "by clicking a few buttons. Um I haven't",
#   'start': 94.88,
#   'duration': 4.239},
#  {'text': 'yet been very close to the systems done',
#   'start': 96.72,
#   'duration': 4.719},
#  {'text': 'it via you know coding. I have done I',
#   'start': 99.119,
#   'duration': 4.32},
#  {'text': "haven't done algorithmic trading yet. Um",
#   'start': 101.439,
#   'duration': 3.441},
#  {'text': "which is what we'll aim to do by the end",
#   'start': 103.439,
#   'duration': 3.841},
#  {'text': "of it. I've done experiments. I know you",
#   'start': 104.88,
#   'duration': 3.879},
#  {'text': 'can squeeze out profits from these',
#   'start': 107.28,
#   'duration': 3.76},
#  {'text': "markets. How do you do that? Uh I'll",
#   'start': 108.759,
#   'duration': 4.121},
#  {'text': "show how to do that manually. Then we'll",
#   'start': 111.04,
#   'duration': 3.2},
#  {'text': 'go through the process of coding it and',
#   'start': 112.88,
#   'duration': 3.919},
#  {'text': 'you know code an ARB bot um and try to',
#   'start': 114.24,
#   'duration': 4.479},
#  {'text': 'see what happens when an IPL match',
#   'start': 116.799,
#   'duration': 4.0},
#  {'text': 'starts ends in the middle and at what',
#   'start': 118.719,
#   'duration': 3.601},
#  {'text': 'point points can you squeeze out',
#   'start': 120.799,
#   'duration': 3.841},
#  {'text': "inefficiencies from these markets. Let's",
#   'start': 122.32,
#   'duration': 3.92},
#  {'text': "get right into it. Um I've created",
#   'start': 124.64,
#   'duration': 3.44},
#  {'text': "slides for this one. So we'll kick",
#   'start': 126.24,
#   'duration': 3.799},
#  {'text': 'things off', 'start': 128.08, 'duration': 4.799},
#  {'text': 'with sports betting arbitrage. This is',
#   'start': 130.039,
#   'duration': 4.2},
#  {'text': "section number one. I'll just take you",
#   'start': 132.879,
#   'duration': 2.801},
#  {'text': 'through what is sports betting, how does',
#   'start': 134.239,
#   'duration': 4.561},
#  {'text': 'it work and what does it mean. Um so',
#   'start': 135.68,
#   'duration': 4.559},
#  {'text': "sports betting basically means let's say",
#   'start': 138.8,
#   'duration': 3.04},
#  {'text': "there's a match between Punjab and",
#   'start': 140.239,
#   'duration': 3.761},
#  {'text': 'Kolkata going on right now. Um this is',
#   'start': 141.84,
#   'duration': 4.08},
#  {'text': "Indian traditional IPL games. This isn't",
#   'start': 144.0,
#   'duration': 3.52},
#  {'text': 'a US versus Canada match. This is a',
#   'start': 145.92,
#   'duration': 4.0},
#  {'text': 'Punjab versus Kolkata match and Punjab',
#   'start': 147.52,
#   'duration': 4.88},
#  {'text': "needs 44 runs to win off 30 balls. Let's",
#   'start': 149.92,
#   'duration': 5.08},
#  {'text': 'say no wickets are down and they need 44',
#   'start': 152.4,
#   'duration': 6.479},
#  {'text': 'runs to win off of 30 balls. Who do you',
#   'start': 155.0,
#   'duration': 5.64},
#  {'text': 'think is going to win? Like probability',
#   'start': 158.879,
#   'duration': 4.161},
#  {'text': 'wise who would you bet on? Probably',
#   'start': 160.64,
#   'duration': 4.8},
#  {'text': 'Punjab. Zero wickets down, 44 runs.',
#   'start': 163.04,
#   'duration': 4.24},
#  {'text': "That's a run rate of eight. isn't too",
#   'start': 165.44,
#   'duration': 4.079},
#  {'text': 'difficult to get in a T20 match with 10',
#   'start': 167.28,
#   'duration': 5.36},
#  {'text': 'wickets at your hand. So you would bet',
#   'start': 169.519,
#   'duration': 6.08},
#  {'text': 'on Punjab at least I would. So if there',
#   'start': 172.64,
#   'duration': 4.319},
#  {'text': 'was a market that exists, if you had a',
#   'start': 175.599,
#   'duration': 2.481},
#  {'text': 'broker that you would call, what would',
#   'start': 176.959,
#   'duration': 2.441},
#  {'text': 'you tell', 'start': 178.08, 'duration': 4.0},
#  {'text': 'them? Take five rupees from me or take',
#   'start': 179.4,
#   'duration': 4.919},
#  {'text': '$5,000 from me and if Punjab wins give',
#   'start': 182.08,
#   'duration': 3.84},
#  {'text': 'me $10,000, right? That is what you',
#   'start': 184.319,
#   'duration': 3.521},
#  {'text': 'would expect.', 'start': 185.92, 'duration': 4.399},
#  {'text': 'But the broker will be like Punjab',
#   'start': 187.84,
#   'duration': 4.24},
#  {'text': 'Punjab is about to win. And hence he',
#   'start': 190.319,
#   'duration': 4.081},
#  {'text': 'will say the broker broker will say give',
#   'start': 192.08,
#   'duration': 5.04},
#  {'text': "me fiveak if Punjab wins I'll give you",
#   'start': 194.4,
#   'duration': 4.72},
#  {'text': 'six lakhs. You will still make a profit',
#   'start': 197.12,
#   'duration': 3.759},
#  {'text': 'but you will not double up your money.',
#   'start': 199.12,
#   'duration': 3.68},
#  {'text': "The probability of Punjab winning isn't",
#   'start': 200.879,
#   'duration': 5.28},
#  {'text': "50% anymore. It's 80%, 90%. And hence",
#   'start': 202.8,
#   'duration': 5.2},
#  {'text': 'the money that you can make is not going',
#   'start': 206.159,
#   'duration': 3.36},
#  {'text': 'to be double. You will not double your',
#   'start': 208.0,
#   'duration': 3.2},
#  {'text': 'money if Punjab wins. Punjab is about to',
#   'start': 209.519,
#   'duration': 5.36},
#  {'text': 'win. Um you will make some you know 1.1x',
#   'start': 211.2,
#   'duration': 5.92},
#  {'text': "1.2x. you'll increase your capital by 10",
#   'start': 214.879,
#   'duration': 4.08},
#  {'text': '20% if they win. If they lose, you lose',
#   'start': 217.12,
#   'duration': 3.759},
#  {'text': "all of it. So it's not very lucrative",
#   'start': 218.959,
#   'duration': 4.041},
#  {'text': 'for you to buy this anymore', 'start': 220.879, 'duration': 4.401},
#  {'text': "because and you're at the risk of losing",
#   'start': 223.0,
#   'duration': 4.92},
#  {'text': 'five lakhs. But also Punjab is about to',
#   'start': 225.28,
#   'duration': 3.679},
#  {'text': "win. There's a very low probability",
#   'start': 227.92,
#   'duration': 3.2},
#  {'text': "Punjab loses. So it's a it's a bet that",
#   'start': 228.959,
#   'duration': 4.481},
#  {'text': 'you have to take. It is a bet. These are',
#   'start': 231.12,
#   'duration': 4.32},
#  {'text': 'traditional sports betting applications.',
#   'start': 233.44,
#   'duration': 4.32},
#  {'text': 'Um and hence if two people sit on a',
#   'start': 235.44,
#   'duration': 4.159},
#  {'text': "table, one person will put in let's say",
#   'start': 237.76,
#   'duration': 4.08},
#  {'text': 'a capital of 20 lakhs. The other person',
#   'start': 239.599,
#   'duration': 4.56},
#  {'text': 'will put in a capital of 5 lakh rupees.',
#   'start': 241.84,
#   'duration': 4.8},
#  {'text': "So there's a total of 25 lakhs in the",
#   'start': 244.159,
#   'duration': 5.44},
#  {'text': 'pool. This person is betting on Punjab.',
#   'start': 246.64,
#   'duration': 5.04},
#  {'text': 'This person is betting on Kolkata.',
#   'start': 249.599,
#   'duration': 4.321},
#  {'text': 'Notice he only had to pay 5 lakh rupees.',
#   'start': 251.68,
#   'duration': 4.48},
#  {'text': 'If Kolkata wins, he takes the pot.',
#   'start': 253.92,
#   'duration': 4.879},
#  {'text': "That's a 5x. He was able to make",
#   'start': 256.16,
#   'duration': 5.199},
#  {'text': 'multiply his money 5x if Kolkata wins.',
#   'start': 258.799,
#   'duration': 3.761},
#  {'text': "But there's a very low probability of",
#   'start': 261.359,
#   'duration': 3.001},
#  {'text': "Kolkata winning. Hence, he's taking this",
#   'start': 262.56,
#   'duration': 4.96},
#  {'text': 'risk. On the other hand, this person is',
#   'start': 264.36,
#   'duration': 4.92},
#  {'text': 'putting in 20 lakhs which is a huge',
#   'start': 267.52,
#   'duration': 3.92},
#  {'text': 'capital. But at the same time, Punjab is',
#   'start': 269.28,
#   'duration': 4.32},
#  {'text': "about to win. Hence it's almost risk-f",
#   'start': 271.44,
#   'duration': 4.72},
#  {'text': 'free almost risk-f free for him to put',
#   'start': 273.6,
#   'duration': 4.64},
#  {'text': 'in 20 lakhs and squeeze out 25 lakh',
#   'start': 276.16,
#   'duration': 4.56},
#  {'text': 'rupees by the end because Punjab the',
#   'start': 278.24,
#   'duration': 5.2},
#  {'text': 'score is so close to Punjab winning it',
#   'start': 280.72,
#   'duration': 4.8},
#  {'text': 'makes sense for this person to take this',
#   'start': 283.44,
#   'duration': 4.319},
#  {'text': 'bet. This is just an example the numbers',
#   'start': 285.52,
#   'duration': 3.52},
#  {'text': 'might change the probabilities might',
#   'start': 287.759,
#   'duration': 3.121},
#  {'text': 'change and you know but the point is',
#   'start': 289.04,
#   'duration': 3.599},
#  {'text': 'there are two parties that are pulling',
#   'start': 290.88,
#   'duration': 3.599},
#  {'text': 'in money together and then one of the',
#   'start': 292.639,
#   'duration': 4.241},
#  {'text': 'parties taking up all the money. Um what',
#   'start': 294.479,
#   'duration': 3.921},
#  {'text': 'money they pull in depends on the',
#   'start': 296.88,
#   'duration': 3.44},
#  {'text': 'probability of the match winning. If the',
#   'start': 298.4,
#   'duration': 3.28},
#  {'text': "match hasn't yet started, it'll be",
#   'start': 300.32,
#   'duration': 2.72},
#  {'text': "closer to 50%, because you don't know",
#   'start': 301.68,
#   'duration': 3.12},
#  {'text': 'how the match will progress. But after',
#   'start': 303.04,
#   'duration': 3.76},
#  {'text': 'one inning is done, then you know you',
#   'start': 304.8,
#   'duration': 3.839},
#  {'text': 'can predict some probability and you',
#   'start': 306.8,
#   'duration': 3.36},
#  {'text': 'know you can find two parties that are',
#   'start': 308.639,
#   'duration': 2.961},
#  {'text': 'willing to put in some money based on',
#   'start': 310.16,
#   'duration': 3.52},
#  {'text': 'the probabilities and take the whole pot',
#   'start': 311.6,
#   'duration': 4.56},
#  {'text': 'when they win. If Punjab wins, that is',
#   'start': 313.68,
#   'duration': 4.799},
#  {'text': 'case number one. Then this was low risk,',
#   'start': 316.16,
#   'duration': 4.64},
#  {'text': 'low reward for this guy. He put in 20',
#   'start': 318.479,
#   'duration': 3.921},
#  {'text': 'lakhs, Punjab was about to win. He took',
#   'start': 320.8,
#   'duration': 4.8},
#  {'text': "out 25 lakhs. That's a 25% profit. It's",
#   'start': 322.4,
#   'duration': 6.079},
#  {'text': "not an amazing profit but it's great for",
#   'start': 325.6,
#   'duration': 4.56},
#  {'text': "you know let's say the last seven eight",
#   'start': 328.479,
#   'duration': 3.841},
#  {'text': 'overs of the match and also very risk-f',
#   'start': 330.16,
#   'duration': 4.08},
#  {'text': 'free because very high probability that',
#   'start': 332.32,
#   'duration': 4.159},
#  {'text': "Punjab is going to win anyways but let's",
#   'start': 334.24,
#   'duration': 5.44},
#  {'text': 'say Punjab is unlucky and slowly you',
#   'start': 336.479,
#   'duration': 4.801},
#  {'text': 'know they wicket start to go down Punjab',
#   'start': 339.68,
#   'duration': 4.16},
#  {'text': 'loses then this guy makes 25 lakhs',
#   'start': 341.28,
#   'duration': 5.68},
#  {'text': "that's a 400% on top of his 5 lakh",
#   'start': 343.84,
#   'duration': 6.32},
#  {'text': 'rupees he did a 5x of his money because',
#   'start': 346.96,
#   'duration': 4.72},
#  {'text': 'he took that risk and his risk ended up',
#   'start': 350.16,
#   'duration': 4.16},
#  {'text': 'paying off that is how traditional',
#   'start': 351.68,
#   'duration': 4.72},
#  {'text': 'sports betting works. You have two',
#   'start': 354.32,
#   'duration': 4.24},
#  {'text': 'people um who are sort of sitting on a',
#   'start': 356.4,
#   'duration': 3.68},
#  {'text': 'table pooling in money based on',
#   'start': 358.56,
#   'duration': 3.96},
#  {'text': 'probabilities. Winner takes', 'start': 360.08, 'duration': 5.679},
#  {'text': 'all. This is not risk-free gambling',
#   'start': 362.52,
#   'duration': 6.04},
#  {'text': 'though. You can lose all of your money.',
#   'start': 365.759,
#   'duration': 6.16},
#  {'text': 'In this case, if Punjab wins, this guy',
#   'start': 368.56,
#   'duration': 4.88},
#  {'text': 'wins, but this guy loses all of it. He',
#   'start': 371.919,
#   'duration': 2.641},
#  {'text': 'was probably prepared because, you know,',
#   'start': 373.44,
#   'duration': 3.36},
#  {'text': 'Punjab was about to win. But if Kolkata',
#   'start': 374.56,
#   'duration': 4.079},
#  {'text': 'wins, this guy wins huge and this guy',
#   'start': 376.8,
#   'duration': 4.48},
#  {'text': "loses 20 lakh rupees. Wasn't very",
#   'start': 378.639,
#   'duration': 4.241},
#  {'text': 'lucrative for him to put in 20 lakhs or',
#   'start': 381.28,
#   'duration': 3.759},
#  {'text': "25 lakhs. But he did. Um, so that's a",
#   'start': 382.88,
#   'duration': 3.92},
#  {'text': 'riskreward. One person will lose. This',
#   'start': 385.039,
#   'duration': 4.0},
#  {'text': 'is a losing strategy in the worst case.',
#   'start': 386.8,
#   'duration': 3.519},
#  {'text': "And we're optimizing for worst case",
#   'start': 389.039,
#   'duration': 3.201},
#  {'text': "here. What we're trying to build is a",
#   'start': 390.319,
#   'duration': 5.201},
#  {'text': 'riskfree strategy. Part two. Can you',
#   'start': 392.24,
#   'duration': 5.76},
#  {'text': 'ever make money risk-free from these',
#   'start': 395.52,
#   'duration': 5.36},
#  {'text': 'markets? Is there any way? Is it even a',
#   'start': 398.0,
#   'duration': 6.88},
#  {'text': '1% possibility? Can you place a bet such',
#   'start': 400.88,
#   'duration': 5.68},
#  {'text': 'that you will always make money',
#   'start': 404.88,
#   'duration': 4.319},
#  {'text': 'irrespective of who wins? The answer is',
#   'start': 406.56,
#   'duration': 6.479},
#  {'text': 'yes. How? You need two markets and there',
#   'start': 409.199,
#   'duration': 5.601},
#  {'text': 'are many markets that exist like this.',
#   'start': 413.039,
#   'duration': 4.081},
#  {'text': "Let's take a example. If there are",
#   'start': 414.8,
#   'duration': 5.6},
#  {'text': 'multiple tables running, if there are',
#   'start': 417.12,
#   'duration': 6.0},
#  {'text': 'multiple tables running, then what might',
#   'start': 420.4,
#   'duration': 3.919},
#  {'text': 'happen would be something like this.',
#   'start': 423.12,
#   'duration': 2.88},
#  {'text': "Let's say there is a table in Delhi",
#   'start': 424.319,
#   'duration': 3.681},
#  {'text': "where one person is sitting but he's",
#   'start': 426.0,
#   'duration': 3.52},
#  {'text': 'waiting for the other person. No one is',
#   'start': 428.0,
#   'duration': 2.96},
#  {'text': 'coming to Delhi and same is true for',
#   'start': 429.52,
#   'duration': 3.119},
#  {'text': 'Bombay. There is one person that is',
#   'start': 430.96,
#   'duration': 4.16},
#  {'text': 'sitting but no one is coming to take the',
#   'start': 432.639,
#   'duration': 4.241},
#  {'text': 'other side of the bet. These people are',
#   'start': 435.12,
#   'duration': 4.079},
#  {'text': 'very anxious. They really want to bet on',
#   'start': 436.88,
#   'duration': 4.159},
#  {'text': 'the Punjab versus Kolkata match but no',
#   'start': 439.199,
#   'duration': 3.681},
#  {'text': 'one is taking their bet. So this guy',
#   'start': 441.039,
#   'duration': 4.0},
#  {'text': 'says yeah even though Punjab is winning',
#   'start': 442.88,
#   'duration': 3.599},
#  {'text': "let's say Punjab isn't winning like this",
#   'start': 445.039,
#   'duration': 3.041},
#  {'text': "let's say you know the match is pretty",
#   'start': 446.479,
#   'duration': 4.16},
#  {'text': 'evenish right now. This person says yeah',
#   'start': 448.08,
#   'duration': 4.559},
#  {'text': "I'm willing to bet 6 lakh rupees. If",
#   'start': 450.639,
#   'duration': 5.12},
#  {'text': "Punjab wins I'll make 10 lakh rupees",
#   'start': 452.639,
#   'duration': 5.12},
#  {'text': 'fair enough you might say Punjab is',
#   'start': 455.759,
#   'duration': 3.521},
#  {'text': 'about to win he should only make 7',
#   'start': 457.759,
#   'duration': 2.961},
#  {'text': "lakhs. Yes but let's say the match",
#   'start': 459.28,
#   'duration': 3.199},
#  {'text': "hasn't started. So this person is like",
#   'start': 460.72,
#   'duration': 3.68},
#  {'text': 'Pab Kolkata feels you know similarish',
#   'start': 462.479,
#   'duration': 4.56},
#  {'text': 'enough he should have paid five lakhs',
#   'start': 464.4,
#   'duration': 5.199},
#  {'text': 'ideally if the probability is 5050%. He',
#   'start': 467.039,
#   'duration': 3.841},
#  {'text': 'should be paying five lakhs and doubling',
#   'start': 469.599,
#   'duration': 2.801},
#  {'text': 'up if it wins going down to zero if it',
#   'start': 470.88,
#   'duration': 4.24},
#  {'text': 'loses. Um but the market is so empty',
#   'start': 472.4,
#   'duration': 4.639},
#  {'text': 'right now there is no liquidity in the',
#   'start': 475.12,
#   'duration': 3.6},
#  {'text': 'market. There is no one sitting on the',
#   'start': 477.039,
#   'duration': 3.641},
#  {'text': "other side. So he's", 'start': 478.72, 'duration': 4.8},
#  {'text': 'like is anyone willing to take six lakh',
#   'start': 480.68,
#   'duration': 4.84},
#  {'text': "bet I'll bet six lakhs you put four",
#   'start': 483.52,
#   'duration': 4.079},
#  {'text': 'lakhs. If I win I take 10. If you win',
#   'start': 485.52,
#   'duration': 3.359},
#  {'text': "you take 10. You'll take much more.",
#   'start': 487.599,
#   'duration': 3.04},
#  {'text': "You'll only have to put four lakhs. So",
#   'start': 488.879,
#   'duration': 4.801},
#  {'text': 'this such table exists in Delhi and a',
#   'start': 490.639,
#   'duration': 5.361},
#  {'text': 'similar table exists in Mumbai. This',
#   'start': 493.68,
#   'duration': 4.239},
#  {'text': "person says okay I'm willing to bet six",
#   'start': 496.0,
#   'duration': 3.52},
#  {'text': 'lakhs on Kolkata. No one is coming to my',
#   'start': 497.919,
#   'duration': 3.361},
#  {'text': 'table. So you just put four lakhs the',
#   'start': 499.52,
#   'duration': 3.76},
#  {'text': 'other party and you know I will make 10',
#   'start': 501.28,
#   'duration': 3.359},
#  {'text': 'lakhs. If you win you will make 10',
#   'start': 503.28,
#   'duration': 3.28},
#  {'text': 'lakhs. Your four will go to 10. My six',
#   'start': 504.639,
#   'duration': 3.601},
#  {'text': 'will go to 10. So please come sit on',
#   'start': 506.56,
#   'duration': 3.6},
#  {'text': 'this table bet with me. There are two',
#   'start': 508.24,
#   'duration': 5.039},
#  {'text': 'people willing to take these bets. But',
#   'start': 510.16,
#   'duration': 4.64},
#  {'text': "unfortunately there isn't enough",
#   'start': 513.279,
#   'duration': 3.521},
#  {'text': "liquidity in Mumbai. There isn't enough",
#   'start': 514.8,
#   'duration': 3.84},
#  {'text': 'liquidity in Delhi. No one is sitting on',
#   'start': 516.8,
#   'duration': 3.679},
#  {'text': 'the other side of the table and hence',
#   'start': 518.64,
#   'duration': 4.319},
#  {'text': "this market is very inefficient. It's",
#   'start': 520.479,
#   'duration': 4.321},
#  {'text': 'inefficient for a different reason but',
#   'start': 522.959,
#   'duration': 3.361},
#  {'text': 'it is not very liquid is the better way',
#   'start': 524.8,
#   'duration': 2.52},
#  {'text': 'to say', 'start': 526.32, 'duration': 4.4},
#  {'text': 'it. No one else is picking their order.',
#   'start': 527.32,
#   'duration': 6.04},
#  {'text': 'Do you see some problem in these orders?',
#   'start': 530.72,
#   'duration': 4.239},
#  {'text': "There is one person sitting here. He's",
#   'start': 533.36,
#   'duration': 3.52},
#  {'text': 'saying I will put six lakhs. If I win I',
#   'start': 534.959,
#   'duration': 4.56},
#  {'text': 'want to make 10 lakhs on Kolkata. Same',
#   'start': 536.88,
#   'duration': 4.639},
#  {'text': 'thing here. I will put six lakhs. I want',
#   'start': 539.519,
#   'duration': 4.801},
#  {'text': 'to make 10 lakhs on Punjab.', 'start': 541.519, 'duration': 5.88},
#  {'text': 'If these people met in', 'start': 544.32, 'duration': 5.44},
#  {'text': 'person, if the broken did not exist in',
#   'start': 547.399,
#   'duration': 4.721},
#  {'text': 'the middle, they would have', 'start': 549.76, 'duration': 4.56},
#  {'text': "said, let's increase the pot to 12",
#   'start': 552.12,
#   'duration': 3.8},
#  {'text': 'lakhs. They would have said you are',
#   'start': 554.32,
#   'duration': 3.12},
#  {'text': 'willing to bet six lakhs, you are',
#   'start': 555.92,
#   'duration': 2.88},
#  {'text': 'willing to bet six lakhs. The port',
#   'start': 557.44,
#   'duration': 3.92},
#  {'text': 'should be 12 lakh rupees, not 10 lakhs.',
#   'start': 558.8,
#   'duration': 4.159},
#  {'text': "Or they would have said, I'll also bet",
#   'start': 561.36,
#   'duration': 3.28},
#  {'text': 'five lakhs, you also bet five lakhs, pot',
#   'start': 562.959,
#   'duration': 3.281},
#  {'text': 'will be 10 lakhs. So this is the',
#   'start': 564.64,
#   'duration': 3.44},
#  {'text': 'inefficiency I was talking about. there',
#   'start': 566.24,
#   'duration': 4.159},
#  {'text': 'are inefficiencies that exist in these',
#   'start': 568.08,
#   'duration': 6.0},
#  {'text': 'markets and when they exist comes the',
#   'start': 570.399,
#   'duration': 5.721},
#  {'text': 'guy in the middle guy doing the', 'start': 574.08, 'duration': 5.6},
#  {'text': 'arbitrage. So rather than uh me going to',
#   'start': 576.12,
#   'duration': 5.48},
#  {'text': "Bombay or Delhi um I'm in both the",
#   'start': 579.68,
#   'duration': 4.719},
#  {'text': 'places somehow and I say yeah I will',
#   'start': 581.6,
#   'duration': 4.16},
#  {'text': 'take your this side of the bet I will',
#   'start': 584.399,
#   'duration': 2.721},
#  {'text': 'take your this side of the bet. So I put',
#   'start': 585.76,
#   'duration': 3.759},
#  {'text': 'up 8 lakh rupees I put up four lakh',
#   'start': 587.12,
#   'duration': 4.399},
#  {'text': 'rupees over here I put up four lakh',
#   'start': 589.519,
#   'duration': 4.961},
#  {'text': 'rupees over here. So if four lakh on',
#   'start': 591.519,
#   'duration': 4.641},
#  {'text': 'Kolkata this guy was betting on Punjab I',
#   'start': 594.48,
#   'duration': 3.28},
#  {'text': 'put four lakh on Kolkata. 10 lakh is the',
#   'start': 596.16,
#   'duration': 3.679},
#  {'text': 'pool. This guy is betting on Kolkata. I',
#   'start': 597.76,
#   'duration': 3.68},
#  {'text': 'put four lakh on Delhi. 10 lakh is the',
#   'start': 599.839,
#   'duration': 5.041},
#  {'text': "pool. Now I'm sitting on two tables. I",
#   'start': 601.44,
#   'duration': 5.48},
#  {'text': 'am down 8 lakh', 'start': 604.88, 'duration': 5.399},
#  {'text': 'rupees. But if Kolkata wins, will I make',
#   'start': 606.92,
#   'duration': 6.44},
#  {'text': 'money? If Delhi wins, will I make money?',
#   'start': 610.279,
#   'duration': 5.0},
#  {'text': "Let's see. Do you understand the final",
#   'start': 613.36,
#   'duration': 4.0},
#  {'text': 'table configuration? Person number one',
#   'start': 615.279,
#   'duration': 4.401},
#  {'text': 'in Delhi says six lakhs Dalonga Duslak',
#   'start': 617.36,
#   'duration': 5.039},
#  {'text': 'Nikala. Punjab wins. Person number two',
#   'start': 619.68,
#   'duration': 4.32},
#  {'text': 'sitting in the air sitting in both the',
#   'start': 622.399,
#   'duration': 4.081},
#  {'text': 'places says okay I will take the other',
#   'start': 624.0,
#   'duration': 4.56},
#  {'text': 'side of this bet I will put in four lak',
#   'start': 626.48,
#   'duration': 4.24},
#  {'text': 'rupees. If Kolkata wins I will take 10',
#   'start': 628.56,
#   'duration': 4.36},
#  {'text': 'lakhs. If Punjab wins I will lose',
#   'start': 630.72,
#   'duration': 4.08},
#  {'text': 'everything. This person is sitting on',
#   'start': 632.92,
#   'duration': 4.359},
#  {'text': "the other table also. He's saying if",
#   'start': 634.8,
#   'duration': 5.52},
#  {'text': 'Delhi wins I will take convert my four',
#   'start': 637.279,
#   'duration': 4.961},
#  {'text': 'lakh to 10 lakhs. If Kolkata wins then',
#   'start': 640.32,
#   'duration': 3.84},
#  {'text': 'of course you take the six lakh sir. You',
#   'start': 642.24,
#   'duration': 4.24},
#  {'text': 'are taking such a ballsy bet of uh',
#   'start': 644.16,
#   'duration': 5.04},
#  {'text': 'betting on Kolkata. What happens if',
#   'start': 646.48,
#   'duration': 4.96},
#  {'text': 'Delhi wins? If Delhi sorry if Punjab',
#   'start': 649.2,
#   'duration': 5.36},
#  {'text': 'wins, this guy made 10 lakhs. I lost on',
#   'start': 651.44,
#   'duration': 4.639},
#  {'text': 'this table unfortunately because I was',
#   'start': 654.56,
#   'duration': 4.32},
#  {'text': 'betting on Kolkata. This my guy made 10',
#   'start': 656.079,
#   'duration': 4.961},
#  {'text': 'lakhs. I made zero over here. But what',
#   'start': 658.88,
#   'duration': 4.16},
#  {'text': 'did I make over here? I made 10 over',
#   'start': 661.04,
#   'duration': 4.0},
#  {'text': 'here because I had taken the opposite',
#   'start': 663.04,
#   'duration': 4.239},
#  {'text': 'side of the bet over here. Irrespective',
#   'start': 665.04,
#   'duration': 5.76},
#  {'text': "of who wins, I will make 10 lakhs. I'm",
#   'start': 667.279,
#   'duration': 6.401},
#  {'text': 'sitting on two tables and my entry price',
#   'start': 670.8,
#   'duration': 5.599},
#  {'text': 'was really low. My entry price here was',
#   'start': 673.68,
#   'duration': 4.64},
#  {'text': 'four lakhs. My entry price here was four',
#   'start': 676.399,
#   'duration': 4.56},
#  {'text': "lakhs and irrespective of who wins I'm",
#   'start': 678.32,
#   'duration': 4.24},
#  {'text': 'going to make 10 lakhs. I might win on',
#   'start': 680.959,
#   'duration': 3.201},
#  {'text': 'this table, I might win on this table.',
#   'start': 682.56,
#   'duration': 3.92},
#  {'text': 'This guy might win or lose. This guy',
#   'start': 684.16,
#   'duration': 4.239},
#  {'text': 'might win or lose. I will win on one',
#   'start': 686.48,
#   'duration': 4.56},
#  {'text': 'table, lose on one table. But overall my',
#   'start': 688.399,
#   'duration': 4.401},
#  {'text': '8 lakh rupees will get converted to 10',
#   'start': 691.04,
#   'duration': 4.4},
#  {'text': 'lakh rupees by the end of it riskfree.',
#   'start': 692.8,
#   'duration': 4.96},
#  {'text': 'Case number one, if Punjab wins, this',
#   'start': 695.44,
#   'duration': 4.079},
#  {'text': "guy makes four lakh rupees. This guy's",
#   'start': 697.76,
#   'duration': 3.68},
#  {'text': 'down 6 lakh rupees. But Harkat in the',
#   'start': 699.519,
#   'duration': 4.401},
#  {'text': 'middle even though he lost on this table',
#   'start': 701.44,
#   'duration': 4.48},
#  {'text': 'won on this table still is up two lakh',
#   'start': 703.92,
#   'duration': 4.24},
#  {'text': 'rupees because he had put in eight lakhs',
#   'start': 705.92,
#   'duration': 4.56},
#  {'text': '44 on both the tables he made 10 lakhs',
#   'start': 708.16,
#   'duration': 5.239},
#  {'text': 'from this specific', 'start': 710.48, 'duration': 4.96},
#  {'text': 'table I had put in four lakhs he had put',
#   'start': 713.399,
#   'duration': 4.201},
#  {'text': 'in six lakhs the combined pool I took',
#   'start': 715.44,
#   'duration': 4.0},
#  {'text': 'over here even though I lost four over',
#   'start': 717.6,
#   'duration': 3.919},
#  {'text': 'here I won six over here I made two lakh',
#   'start': 719.44,
#   'duration': 4.959},
#  {'text': 'rupees what happens if Kolkata wins this',
#   'start': 721.519,
#   'duration': 4.801},
#  {'text': "guy's down six lakh rupees this guy's up",
#   'start': 724.399,
#   'duration': 3.68},
#  {'text': 'four lakh rupees I still make 2 lakh',
#   'start': 726.32,
#   'duration': 4.48},
#  {'text': 'rupees because now I won on this table',
#   'start': 728.079,
#   'duration': 4.88},
#  {'text': 'irrespective of which table I win on I',
#   'start': 730.8,
#   'duration': 4.56},
#  {'text': 'will make 10 lakhs I only put in 8 lakhs',
#   'start': 732.959,
#   'duration': 4.801},
#  {'text': 'hence I have a profit of two lakh rupees',
#   'start': 735.36,
#   'duration': 3.84},
#  {'text': 'what is this called this is called',
#   'start': 737.76,
#   'duration': 4.16},
#  {'text': 'arbituring if there are two markets that',
#   'start': 739.2,
#   'duration': 5.92},
#  {'text': 'exist where the price difference um',
#   'start': 741.92,
#   'duration': 4.64},
#  {'text': 'where there is inefficiency not price',
#   'start': 745.12,
#   'duration': 2.64},
#  {'text': 'difference but there is inefficiency',
#   'start': 746.56,
#   'duration': 3.519},
#  {'text': 'what does inefficiency mean okay there',
#   'start': 747.76,
#   'duration': 3.6},
#  {'text': 'is a bet that should have happened',
#   'start': 750.079,
#   'duration': 2.88},
#  {'text': 'directly between these two guys at a',
#   'start': 751.36,
#   'duration': 3.76},
#  {'text': 'much better price for them this guy was',
#   'start': 752.959,
#   'duration': 3.521},
#  {'text': 'willing to put 6 for 10 this guy was',
#   'start': 755.12,
#   'duration': 3.12},
#  {'text': 'willing to put 6 for 10 if they met in',
#   'start': 756.48,
#   'duration': 3.68},
#  {'text': 'person they would have negotiated a',
#   'start': 758.24,
#   'duration': 3.839},
#  {'text': 'better deal. They would have said 55',
#   'start': 760.16,
#   'duration': 3.679},
#  {'text': "let's decrease our risk or they would",
#   'start': 762.079,
#   'duration': 4.481},
#  {'text': "have said 1212 let's increase our final",
#   'start': 763.839,
#   'duration': 6.0},
#  {'text': 'outcome since they were not able to meet',
#   'start': 766.56,
#   'duration': 5.6},
#  {'text': 'came someone in the middle to squeeze',
#   'start': 769.839,
#   'duration': 4.721},
#  {'text': 'out this inefficiency and you know make',
#   'start': 772.16,
#   'duration': 4.799},
#  {'text': 'the extra two lakhs himself. Ideally',
#   'start': 774.56,
#   'duration': 3.6},
#  {'text': 'that two lakh should be shared amongst',
#   'start': 776.959,
#   'duration': 3.041},
#  {'text': 'these guys. Either they should decrease',
#   'start': 778.16,
#   'duration': 3.119},
#  {'text': 'their capital or they should increase',
#   'start': 780.0,
#   'duration': 3.2},
#  {'text': 'the final outcome. That two lakh rupees',
#   'start': 781.279,
#   'duration': 3.68},
#  {'text': 'that should have been between these two',
#   'start': 783.2,
#   'duration': 3.04},
#  {'text': "since they don't know each other and",
#   'start': 784.959,
#   'duration': 2.721},
#  {'text': 'they are desperate for this offer. They',
#   'start': 786.24,
#   'duration': 3.839},
#  {'text': 'took my offer and I made the risk-free',
#   'start': 787.68,
#   'duration': 3.839},
#  {'text': "return in the middle. That's how",
#   'start': 790.079,
#   'duration': 4.0},
#  {'text': 'arbituring works in the real world. But',
#   'start': 791.519,
#   'duration': 4.481},
#  {'text': "unfortunately I am a human. I can't sit",
#   'start': 794.079,
#   'duration': 3.56},
#  {'text': 'on two tables like this.', 'start': 796.0, 'duration': 4.56},
#  {'text': 'Um and anyways you know this is not the',
#   'start': 797.639,
#   'duration': 4.681},
#  {'text': 'best strategy to do. um because there',
#   'start': 800.56,
#   'duration': 4.24},
#  {'text': 'are people involved and you know you',
#   'start': 802.32,
#   'duration': 4.24},
#  {'text': "don't know at a microcond who is betting",
#   'start': 804.8,
#   'duration': 5.279},
#  {'text': 'what um and hence even though this is a',
#   'start': 806.56,
#   'duration': 5.36},
#  {'text': "great strategy on paper um you can't",
#   'start': 810.079,
#   'duration': 3.361},
#  {'text': "really execute it uh because there's a",
#   'start': 811.92,
#   'duration': 3.28},
#  {'text': 'lot of people management involved market',
#   'start': 813.44,
#   'duration': 3.6},
#  {'text': 'makers make money in both of these cases',
#   'start': 815.2,
#   'duration': 4.0},
#  {'text': 'I am the market maker why am I the',
#   'start': 817.04,
#   'duration': 3.52},
#  {'text': "market maker because I'm making the",
#   'start': 819.2,
#   'duration': 3.52},
#  {'text': 'market the market was illquid before I',
#   'start': 820.56,
#   'duration': 3.6},
#  {'text': 'came this guy was sitting no one was',
#   'start': 822.72,
#   'duration': 2.64},
#  {'text': 'taking his bet this guy was sitting no',
#   'start': 824.16,
#   'duration': 3.679},
#  {'text': 'one was taking his bet I came and I made',
#   'start': 825.36,
#   'duration': 5.8},
#  {'text': 'the market I sat on both the tables',
#   'start': 827.839,
#   'duration': 5.841},
#  {'text': 'beats and I was able to squeeze the',
#   'start': 831.16,
#   'duration': 4.919},
#  {'text': 'inefficiency out of this. Um, this',
#   'start': 833.68,
#   'duration': 4.24},
#  {'text': 'relies on the assumption that traders',
#   'start': 836.079,
#   'duration': 4.721},
#  {'text': 'are not aware of all the markets',
#   'start': 837.92,
#   'duration': 4.88},
#  {'text': "assumption. Okay, these guys don't can't",
#   'start': 840.8,
#   'duration': 3.279},
#  {'text': 'talk to each other directly. If they',
#   'start': 842.8,
#   'duration': 2.479},
#  {'text': 'could talk to each other, they would of',
#   'start': 844.079,
#   'duration': 2.641},
#  {'text': 'course negotiate a better deal amongst',
#   'start': 845.279,
#   'duration': 3.441},
#  {'text': "themselves. Since they weren't, I had",
#   'start': 846.72,
#   'duration': 5.28},
#  {'text': 'just the extra knowledge of two tables',
#   'start': 848.72,
#   'duration': 4.72},
#  {'text': 'existing. I sat on both of them, made',
#   'start': 852.0,
#   'duration': 3.519},
#  {'text': 'some money in the middle. Cool. But of',
#   'start': 853.44,
#   'duration': 3.04},
#  {'text': "course, you don't want to do this",
#   'start': 855.519,
#   'duration': 3.521},
#  {'text': 'offline. Hence, you will do this online.',
#   'start': 856.48,
#   'duration': 4.56},
#  {'text': 'So before we get into doing this online,',
#   'start': 859.04,
#   'duration': 3.76},
#  {'text': "it's very easy to understand how offline",
#   'start': 861.04,
#   'duration': 3.52},
#  {'text': 'um you know betting would work. Online',
#   'start': 862.8,
#   'duration': 4.32},
#  {'text': "is a little tricky. Let's understand how",
#   'start': 864.56,
#   'duration': 4.639},
#  {'text': 'online brokers work. How can you place',
#   'start': 867.12,
#   'duration': 4.88},
#  {'text': 'similar bets on an online platform? All',
#   'start': 869.199,
#   'duration': 5.44},
#  {'text': 'right. How does similar betting happen',
#   'start': 872.0,
#   'duration': 5.279},
#  {'text': 'in the online phase? How should you do',
#   'start': 874.639,
#   'duration': 4.801},
#  {'text': 'this? You should probably not deal with',
#   'start': 877.279,
#   'duration': 3.68},
#  {'text': "physical human beings when you're trying",
#   'start': 879.44,
#   'duration': 4.48},
#  {'text': 'to bet on, you know, a market like this.',
#   'start': 880.959,
#   'duration': 4.56},
#  {'text': 'You should bet online. But how does',
#   'start': 883.92,
#   'duration': 3.919},
#  {'text': 'online gambling work? What technical',
#   'start': 885.519,
#   'duration': 4.161},
#  {'text': 'jargon do you need to know? Um when',
#   'start': 887.839,
#   'duration': 3.601},
#  {'text': "you're trying to place these bets, when",
#   'start': 889.68,
#   'duration': 3.92},
#  {'text': "you're trying to bet on Punjab or",
#   'start': 891.44,
#   'duration': 5.04},
#  {'text': 'Kolkata um and where does that happen?',
#   'start': 893.6,
#   'duration': 4.799},
#  {'text': 'The answer is using something called',
#   'start': 896.48,
#   'duration': 4.08},
#  {'text': "sports books or order books. They're a",
#   'start': 898.399,
#   'duration': 3.841},
#  {'text': 'slightly new concept in India right now.',
#   'start': 900.56,
#   'duration': 4.0},
#  {'text': 'Uh but have been running in the US for',
#   'start': 902.24,
#   'duration': 3.839},
#  {'text': 'Super Bowl or you might have seen a',
#   'start': 904.56,
#   'duration': 3.839},
#  {'text': 'bunch of uh horse gambling that happens.',
#   'start': 906.079,
#   'duration': 5.12},
#  {'text': 'Um over there u you do something very',
#   'start': 908.399,
#   'duration': 4.401},
#  {'text': 'close to what a stock market does which',
#   'start': 911.199,
#   'duration': 3.2},
#  {'text': 'is you create something called order',
#   'start': 912.8,
#   'duration': 3.2},
#  {'text': "books or in this case they're called",
#   'start': 914.399,
#   'duration': 4.481},
#  {'text': 'sports books. Um one such platform that',
#   'start': 916.0,
#   'duration': 5.36},
#  {'text': 'exists in India that lets you trade',
#   'start': 918.88,
#   'duration': 4.84},
#  {'text': 'based on these order books is called',
#   'start': 921.36,
#   'duration': 6.08},
#  {'text': 'probo. Probo is not for just cricket-',
#   'start': 923.72,
#   'duration': 5.96},
#  {'text': 'based trading. You can trade on other',
#   'start': 927.44,
#   'duration': 5.12},
#  {'text': 'things as well. Here for example you can',
#   'start': 929.68,
#   'duration': 4.64},
#  {'text': 'trade on something like will Narendra',
#   'start': 932.56,
#   'duration': 4.959},
#  {'text': 'Modi win the next election to a similar',
#   'start': 934.32,
#   'duration': 5.04},
#  {'text': 'market will exist. You can bet your',
#   'start': 937.519,
#   'duration': 4.081},
#  {'text': 'money if Narendra Modi wins then you',
#   'start': 939.36,
#   'duration': 3.839},
#  {'text': 'make double up your money or whatever.',
#   'start': 941.6,
#   'duration': 3.84},
#  {'text': 'If he loses you lose your money. Um so',
#   'start': 943.199,
#   'duration': 4.64},
#  {'text': 'many such markets exist. We are niching',
#   'start': 945.44,
#   'duration': 5.68},
#  {'text': 'down on just one such market which is uh',
#   'start': 947.839,
#   'duration': 5.68},
#  {'text': 'IPL or cricket matches. How do they',
#   'start': 951.12,
#   'duration': 4.56},
#  {'text': "work? So IPL is currently I don't know",
#   'start': 953.519,
#   'duration': 4.081},
#  {'text': 'disabled or something or not happening',
#   'start': 955.68,
#   'duration': 3.92},
#  {'text': 'and hence I found a different market for',
#   'start': 957.6,
#   'duration': 4.08},
#  {'text': 'European cricket series I would assume',
#   'start': 959.6,
#   'duration': 4.56},
#  {'text': 'this is an IPL of Europe over there',
#   'start': 961.68,
#   'duration': 4.959},
#  {'text': "there's this match between Ariana K to",
#   'start': 964.16,
#   'duration': 4.4},
#  {'text': 'win against the match against this other',
#   'start': 966.639,
#   'duration': 4.801},
#  {'text': 'company so the market says okay is',
#   'start': 968.56,
#   'duration': 5.6},
#  {'text': 'Ariana K this team going to win or not',
#   'start': 971.44,
#   'duration': 6.319},
#  {'text': 'and right below you see an order book',
#   'start': 974.16,
#   'duration': 6.32},
#  {'text': 'this order book is a bunch of open',
#   'start': 977.759,
#   'duration': 4.721},
#  {'text': "orders I repeat it's similar to",
#   'start': 980.48,
#   'duration': 4.08},
#  {'text': 'something like this when these two',
#   'start': 982.48,
#   'duration': 4.479},
#  {'text': 'people were sitting with some orders on',
#   'start': 984.56,
#   'duration': 4.8},
#  {'text': 'the table. You could think of this like',
#   'start': 986.959,
#   'duration': 4.401},
#  {'text': 'an order book. These are open orders',
#   'start': 989.36,
#   'duration': 3.839},
#  {'text': 'which means someone is willing to take',
#   'start': 991.36,
#   'duration': 4.56},
#  {'text': 'that bet but no one has taken it yet. In',
#   'start': 993.199,
#   'duration': 4.961},
#  {'text': 'this case, these two orders existed on',
#   'start': 995.92,
#   'duration': 3.839},
#  {'text': 'the order book until I came in the',
#   'start': 998.16,
#   'duration': 3.119},
#  {'text': 'middle and took the other side of the',
#   'start': 999.759,
#   'duration': 4.0},
#  {'text': 'bet. So when people are willing to place',
#   'start': 1001.279,
#   'duration': 5.12},
#  {'text': 'a bet but no one else has taken that',
#   'start': 1003.759,
#   'duration': 5.121},
#  {'text': 'bet, that bet shows up on this order',
#   'start': 1006.399,
#   'duration': 4.641},
#  {'text': 'book. So when you see this page what it',
#   'start': 1008.88,
#   'duration': 5.6},
#  {'text': 'means is K Ariana Kif the very first',
#   'start': 1011.04,
#   'duration': 6.64},
#  {'text': 'team if you think like they will win you',
#   'start': 1014.48,
#   'duration': 7.039},
#  {'text': 'can buy their stock for 7.5 rupees and',
#   'start': 1017.68,
#   'duration': 6.48},
#  {'text': 'if they win it goes up to 10 rupees so',
#   'start': 1021.519,
#   'duration': 5.601},
#  {'text': "you'll make a profit of whatever 30 40%",
#   'start': 1024.16,
#   'duration': 4.639},
#  {'text': 'in case you buy this and they actually',
#   'start': 1027.12,
#   'duration': 3.679},
#  {'text': 'win. If they lose of course your 7.5',
#   'start': 1028.799,
#   'duration': 4.961},
#  {'text': 'rupees goes down to zero. On the other',
#   'start': 1030.799,
#   'duration': 5.12},
#  {'text': 'side there is another order book which',
#   'start': 1033.76,
#   'duration': 4.799},
#  {'text': 'says if you buy you can buy the other',
#   'start': 1035.919,
#   'duration': 4.961},
#  {'text': 'team car winning stock for three rupees.',
#   'start': 1038.559,
#   'duration': 4.081},
#  {'text': 'So you only have to give three rupees.',
#   'start': 1040.88,
#   'duration': 4.4},
#  {'text': "It'll go up to 10 rupees if the Malmo",
#   'start': 1042.64,
#   'duration': 5.199},
#  {'text': "team wins. So as you can see it's",
#   'start': 1045.28,
#   'duration': 4.399},
#  {'text': 'basically both the orders available just',
#   'start': 1047.839,
#   'duration': 3.921},
#  {'text': 'like we had two tables over there. We',
#   'start': 1049.679,
#   'duration': 4.081},
#  {'text': 'have two order books over here. Why an',
#   'start': 1051.76,
#   'duration': 3.84},
#  {'text': 'order book? Because multiple people want',
#   'start': 1053.76,
#   'duration': 4.24},
#  {'text': 'to trade not just one. And hence you can',
#   'start': 1055.6,
#   'duration': 6.4},
#  {'text': 'see at 7.5 rupees there are 336 orders',
#   'start': 1058.0,
#   'duration': 6.32},
#  {'text': "available. Which means let's say 20",
#   'start': 1062.0,
#   'duration': 5.28},
#  {'text': 'people are you know some people have 20',
#   'start': 1064.32,
#   'duration': 4.32},
#  {'text': 'quantities that they are willing to take',
#   'start': 1067.28,
#   'duration': 2.88},
#  {'text': 'the other side of some people have 40',
#   'start': 1068.64,
#   'duration': 2.72},
#  {'text': 'quantities some people have 10', 'start': 1070.16, 'duration': 4.2},
#  {'text': 'quantities some people have one',
#   'start': 1071.36,
#   'duration': 6.08},
#  {'text': 'quantity stocks available 336 stocks are',
#   'start': 1074.36,
#   'duration': 5.24},
#  {'text': 'available to be purchased at this price',
#   'start': 1077.44,
#   'duration': 4.64},
#  {'text': 'so if you feel like Ariana K is going to',
#   'start': 1079.6,
#   'duration': 6.199},
#  {'text': 'win you can actually bet 7.5 rupees into',
#   'start': 1082.08,
#   'duration': 6.719},
#  {'text': '336 and if they win you will make 10',
#   'start': 1085.799,
#   'duration': 6.641},
#  {'text': "into 336 that's 33,000 rupees right",
#   'start': 1088.799,
#   'duration': 7.201},
#  {'text': '33,600 rupees. If they lose then your',
#   'start': 1092.44,
#   'duration': 7.239},
#  {'text': '7.5 into 336 goes down to zero. That is',
#   'start': 1096.0,
#   'duration': 5.6},
#  {'text': 'what this order book means. Whenever you',
#   'start': 1099.679,
#   'duration': 4.0},
#  {'text': 'see a book like this and this is not a',
#   'start': 1101.6,
#   'duration': 5.36},
#  {'text': 'sports specific thing. It appears in',
#   'start': 1103.679,
#   'duration': 5.041},
#  {'text': "exchanges as well like whenever you're",
#   'start': 1106.96,
#   'duration': 4.32},
#  {'text': 'trading on Serodha or any other you know',
#   'start': 1108.72,
#   'duration': 5.839},
#  {'text': 'uh exchange you can clearly see order',
#   'start': 1111.28,
#   'duration': 4.8},
#  {'text': 'books over there and they mean the same',
#   'start': 1114.559,
#   'duration': 4.081},
#  {'text': 'thing. If this stock is willing to be',
#   'start': 1116.08,
#   'duration': 4.4},
#  {'text': 'bought at a certain price, willing to be',
#   'start': 1118.64,
#   'duration': 3.52},
#  {'text': 'sold at a certain price. This thing that',
#   'start': 1120.48,
#   'duration': 5.0},
#  {'text': 'you see over here when you go to',
#   'start': 1122.16,
#   'duration': 5.68},
#  {'text': 'backpack.exchange/trade/soul USDC, this',
#   'start': 1125.48,
#   'duration': 4.92},
#  {'text': 'thing is the order book of the backpack',
#   'start': 1127.84,
#   'duration': 4.64},
#  {'text': 'exchange. And similarly, this thing is',
#   'start': 1130.4,
#   'duration': 3.639},
#  {'text': 'the order book of', 'start': 1132.48, 'duration': 4.319},
#  {'text': 'the this specific market which is will',
#   'start': 1134.039,
#   'duration': 4.921},
#  {'text': 'this team win against this team. You can',
#   'start': 1136.799,
#   'duration': 3.76},
#  {'text': 'if you feel like you want to gamble you',
#   'start': 1138.96,
#   'duration': 6.079},
#  {'text': 'can spend 7.5 into 336 or 7.5 into 2',
#   'start': 1140.559,
#   'duration': 5.761},
#  {'text': 'depends on how much money you want to',
#   'start': 1145.039,
#   'duration': 3.201},
# ...
#   'start': 1840.32,
#   'duration': 5.599},
#  {'text': '8:24 I placed an order here at 8:26 I',
#   'start': 1842.48,
#   'duration': 7.28},
#  {'text': 'placed an order here to buy Delhi from',
#   'start': 1845.919,
#   'duration': 7.76},
#  {'text': 'Probo and Hyderabad from Poly Market.',
#   'start': 1849.76,
#   'duration': 5.279},
#  {'text': "Let's look at the exact quantities that",
#   'start': 1853.679,
#   'duration': 3.281},
#  {'text': 'I bought because this was very confusing',
#   'start': 1855.039,
#   'duration': 4.161},
#  {'text': 'uh because here the quantities are so',
#   'start': 1856.96,
#   'duration': 5.199},
#  {'text': 'the the currency is INR 5.2 2 rupees',
#   'start': 1859.2,
#   'duration': 5.359},
#  {'text': 'here the currency is cents which means',
#   'start': 1862.159,
#   'duration': 4.561},
#  {'text': 'eventually dollars to I when I was',
#   'start': 1864.559,
#   'duration': 4.72},
#  {'text': 'buying one quantity here I was spending',
#   'start': 1866.72,
#   'duration': 4.72},
#  {'text': '47 cents when I was buying one quantity',
#   'start': 1869.279,
#   'duration': 4.64},
#  {'text': 'here I was spending 5.2 2 rupees. So I',
#   'start': 1871.44,
#   'duration': 5.359},
#  {'text': 'had to buy you know 70 quantities to get',
#   'start': 1873.919,
#   'duration': 4.24},
#  {'text': 'an equivalent number over here or',
#   'start': 1876.799,
#   'duration': 3.24},
#  {'text': 'something like that. Right? Math',
#   'start': 1878.159,
#   'duration': 3.921},
#  {'text': 'confusing because the currencies are',
#   'start': 1880.039,
#   'duration': 3.64},
#  {'text': 'different. Um if the currencies were',
#   'start': 1882.08,
#   'duration': 2.719},
#  {'text': 'same it would have been very simple for',
#   'start': 1883.679,
#   'duration': 2.801},
#  {'text': 'me. I would have selected 100 as the',
#   'start': 1884.799,
#   'duration': 2.961},
#  {'text': 'quantity over here. I would have',
#   'start': 1886.48,
#   'duration': 2.72},
#  {'text': 'selected 100 as the quantity over here.',
#   'start': 1887.76,
#   'duration': 3.36},
#  {'text': 'Now I have 100 100 stocks of both.',
#   'start': 1889.2,
#   'duration': 3.52},
#  {'text': 'Whoever wins I will make $100', 'start': 1891.12, 'duration': 4.4},
#  {'text': 'irrespective of who wins. That will not',
#   'start': 1892.72,
#   'duration': 6.48},
#  {'text': 'be true if you know I do some wrong math',
#   'start': 1895.52,
#   'duration': 4.879},
#  {'text': 'over here and I buy the different',
#   'start': 1899.2,
#   'duration': 2.719},
#  {'text': 'quantities the wrong quantities. I',
#   'start': 1900.399,
#   'duration': 2.961},
#  {'text': 'always I had to optimize the quantity',
#   'start': 1901.919,
#   'duration': 4.24},
#  {'text': 'number very heavily because both of',
#   'start': 1903.36,
#   'duration': 4.72},
#  {'text': "these don't exist in the same currency.",
#   'start': 1906.159,
#   'duration': 4.081},
#  {'text': 'Same', 'start': 1908.08, 'duration': 2.16},
#  {'text': 'currency. How did I u trade? Um so these',
#   'start': 1911.88,
#   'duration': 6.76},
#  {'text': 'were the orders that I placed on poly',
#   'start': 1916.559,
#   'duration': 4.161},
#  {'text': 'market. I bought one for 46 and suddenly',
#   'start': 1918.64,
#   'duration': 4.639},
#  {'text': 'the arb actually went up to 2%. I uh I',
#   'start': 1920.72,
#   'duration': 4.0},
#  {'text': 'bought it for 47 and then it was',
#   'start': 1923.279,
#   'duration': 4.321},
#  {'text': 'available for 46. Um so literally the',
#   'start': 1924.72,
#   'duration': 5.679},
#  {'text': 'ARB went up from 1% to 2% you know some',
#   'start': 1927.6,
#   'duration': 4.64},
#  {'text': 'minutes after I bought um so I bought',
#   'start': 1930.399,
#   'duration': 5.28},
#  {'text': 'this also I bought $117 for47 for',
#   'start': 1932.24,
#   'duration': 6.64},
#  {'text': 'Sunriser Hyderabad I bought $48 worth of',
#   'start': 1935.679,
#   'duration': 5.921},
#  {'text': 'um which means $16 quantities for 46',
#   'start': 1938.88,
#   'duration': 5.84},
#  {'text': 'cents of uh Hyderabad again orders',
#   'start': 1941.6,
#   'duration': 5.28},
#  {'text': 'please one for 47 cents where I bought',
#   'start': 1944.72,
#   'duration': 4.24},
#  {'text': '250 quantities 1 for 46 cents when I',
#   'start': 1946.88,
#   'duration': 4.799},
#  {'text': 'bought 106 quantities um I have spent',
#   'start': 1948.96,
#   'duration': 5.599},
#  {'text': '$106 in one market over here just how I',
#   'start': 1951.679,
#   'duration': 4.961},
#  {'text': 'had put four lakh rupees in the Delhi',
#   'start': 1954.559,
#   'duration': 4.24},
#  {'text': 'market. Then on the other side in this',
#   'start': 1956.64,
#   'duration': 4.159},
#  {'text': 'other market I placed a few orders',
#   'start': 1958.799,
#   'duration': 4.321},
#  {'text': 'because which you can only on ramp 5,000',
#   'start': 1960.799,
#   'duration': 4.081},
#  {'text': 'at a time over here. Uh to slowly slowly',
#   'start': 1963.12,
#   'duration': 5.439},
#  {'text': 'I on ramp and I spent around $178. This',
#   'start': 1964.88,
#   'duration': 5.6},
#  {'text': 'is assuming some you know dollar price',
#   'start': 1968.559,
#   'duration': 3.761},
#  {'text': "of $85 rupees which is a challenge. I'll",
#   'start': 1970.48,
#   'duration': 2.88},
#  {'text': "come to that later why that's a",
#   'start': 1972.32,
#   'duration': 2.64},
#  {'text': 'challenge. But assuming the dollar price',
#   'start': 1973.36,
#   'duration': 5.039},
#  {'text': 'was uh 85 I spent $178 over here. You',
#   'start': 1974.96,
#   'duration': 5.439},
#  {'text': 'might ask why did you spend more over',
#   'start': 1978.399,
#   'duration': 3.561},
#  {'text': 'here less over here?', 'start': 1980.399, 'duration': 5.201},
#  {'text': 'same answer you know if the price over',
#   'start': 1981.96,
#   'duration': 5.4},
#  {'text': 'here is less the amount I want the same',
#   'start': 1985.6,
#   'duration': 3.36},
#  {'text': 'quantity to be bought on both the sides',
#   'start': 1987.36,
#   'duration': 3.28},
#  {'text': "I don't want the same price to be spent",
#   'start': 1988.96,
#   'duration': 5.12},
#  {'text': 'from my pocket same quantity to if you',
#   'start': 1990.64,
#   'duration': 6.08},
#  {'text': 'know if the currency was the same and',
#   'start': 1994.08,
#   'duration': 4.16},
#  {'text': 'here something was available for 10 and',
#   'start': 1996.72,
#   'duration': 3.28},
#  {'text': 'something was available for 90 I would',
#   'start': 1998.24,
#   'duration': 3.679},
#  {'text': 'have spent 900 rupees over here spend',
#   'start': 2000.0,
#   'duration': 4.08},
#  {'text': 'only 100 rupees here to make sure',
#   'start': 2001.919,
#   'duration': 4.48},
#  {'text': 'quantity now irrespective of who wins',
#   'start': 2004.08,
#   'duration': 4.0},
#  {'text': "I'm going to reach 100 rupees by the end",
#   'start': 2006.399,
#   'duration': 4.4},
#  {'text': 'of it same thing is true over here okay',
#   'start': 2008.08,
#   'duration': 4.0},
#  {'text': "I don't have to make sure okay I'm",
#   'start': 2010.799,
#   'duration': 3.201},
#  {'text': 'spending equal amount of money where',
#   'start': 2012.08,
#   'duration': 3.76},
#  {'text': "there is it's available for cheaper I'll",
#   'start': 2014.0,
#   'duration': 3.12},
#  {'text': "spend less money where it's available",
#   'start': 2015.84,
#   'duration': 3.28},
#  {'text': 'for more I will spend more money um but',
#   'start': 2017.12,
#   'duration': 3.52},
#  {'text': "the quantities that I'm buying should be",
#   'start': 2019.12,
#   'duration': 3.6},
#  {'text': 'similar the final outcome should be',
#   'start': 2020.64,
#   'duration': 3.519},
#  {'text': 'similar the final passage of money',
#   'start': 2022.72,
#   'duration': 2.799},
#  {'text': 'irrespective of this wins or this wins',
#   'start': 2024.159,
#   'duration': 3.12},
#  {'text': 'should be the same that is what you need',
#   'start': 2025.519,
#   'duration': 3.52},
#  {'text': "to optimize for that's very easy to do",
#   'start': 2027.279,
#   'duration': 3.841},
#  {'text': 'if the currency is the same since the',
#   'start': 2029.039,
#   'duration': 3.52},
#  {'text': 'currency is different over here I was',
#   'start': 2031.12,
#   'duration': 3.12},
#  {'text': 'doing a bunch of calculator math and',
#   'start': 2032.559,
#   'duration': 5.24},
#  {'text': 'assuming a dollar price to figure',
#   'start': 2034.24,
#   'duration': 6.08},
#  {'text': 'out slowly slowly I was buying for you',
#   'start': 2037.799,
#   'duration': 4.281},
#  {'text': 'know whatever or eventually I think I',
#   'start': 2040.32,
#   'duration': 2.719},
#  {'text': 'first bought this then this then this',
#   'start': 2042.08,
#   'duration': 1.92},
#  {'text': 'then this and then eventually you know',
#   'start': 2043.039,
#   'duration': 4.48},
#  {'text': 'bought more to realize this is the final',
#   'start': 2044.0,
#   'duration': 5.28},
#  {'text': 'you know investment that I need to make.',
#   'start': 2047.519,
#   'duration': 3.441},
#  {'text': "So it's I'm completely delta neutral by",
#   'start': 2049.28,
#   'duration': 2.52},
#  {'text': 'the end of', 'start': 2050.96, 'duration': 3.919},
#  {'text': 'it. Some numbers I put over here. I was',
#   'start': 2051.8,
#   'duration': 5.24},
#  {'text': "hoping to I'm delta neutral. I will make",
#   'start': 2054.879,
#   'duration': 3.921},
#  {'text': 'money no matter who wins. But that was',
#   'start': 2057.04,
#   'duration': 3.599},
#  {'text': 'not true by the end of it because of the',
#   'start': 2058.8,
#   'duration': 3.44},
#  {'text': 'currency math that I did that was wrong.',
#   'start': 2060.639,
#   'duration': 2.801},
#  {'text': "So let's see what the final outcome",
#   'start': 2062.24,
#   'duration': 2.48},
#  {'text': 'would have been. This is the money that',
#   'start': 2063.44,
#   'duration': 5.6},
#  {'text': 'I spent $166 over here to buy some 106 +',
#   'start': 2064.72,
#   'duration': 7.04},
#  {'text': '250 quantities. That means if they win,',
#   'start': 2069.04,
#   'duration': 6.599},
#  {'text': "I would have made $250 plus 106 that's",
#   'start': 2071.76,
#   'duration': 5.919},
#  {'text': '$356. If they lost, then I would have',
#   'start': 2075.639,
#   'duration': 3.24},
#  {'text': 'made zero over here. But I would have',
#   'start': 2077.679,
#   'duration': 2.72},
#  {'text': 'made a similar number over here around',
#   'start': 2078.879,
#   'duration': 4.601},
#  {'text': "$356. I've put close to", 'start': 2080.399, 'duration': 5.361},
#  {'text': "$340. If you add these two up, it's",
#   'start': 2083.48,
#   'duration': 5.32},
#  {'text': 'closer to some 338, 335 number,',
#   'start': 2085.76,
#   'duration': 5.919},
#  {'text': 'something like that. Um but irrespective',
#   'start': 2088.8,
#   'duration': 5.4},
#  {'text': 'of where I won I would have made $340 to',
#   'start': 2091.679,
#   'duration': 6.081},
#  {'text': 'profit because there was an R above 1%',
#   'start': 2094.2,
#   'duration': 5.56},
#  {'text': 'that existed. Whenever I was buying this',
#   'start': 2097.76,
#   'duration': 4.64},
#  {'text': 'for 5.2 I was buying this for either 47',
#   'start': 2099.76,
#   'duration': 7.92},
#  {'text': 'or 46 47 46 the other side was available',
#   'start': 2102.4,
#   'duration': 7.84},
#  {'text': "for 52. If you add them up it's 98 or",
#   'start': 2107.68,
#   'duration': 4.96},
#  {'text': '99. There was always some profit left',
#   'start': 2110.24,
#   'duration': 4.879},
#  {'text': 'for me to squeeze by the end. If',
#   'start': 2112.64,
#   'duration': 5.36},
#  {'text': 'Hyderabad won, yeah, I had bet for',
#   'start': 2115.119,
#   'duration': 5.121},
#  {'text': 'Sunrise Hyderabad. I had bet for the',
#   'start': 2118.0,
#   'duration': 4.32},
#  {'text': 'other party. If Hyderabad won, I would',
#   'start': 2120.24,
#   'duration': 4.0},
#  {'text': 'have lost all the money over here, but I',
#   'start': 2122.32,
#   'duration': 4.96},
#  {'text': 'would have made money over here. I had',
#   'start': 2124.24,
#   'duration': 6.119},
#  {'text': '106 plus 250 quantities that is',
#   'start': 2127.28,
#   'duration': 5.76},
#  {'text': "356 356. I would have made 356. I don't",
#   'start': 2130.359,
#   'duration': 4.841},
#  {'text': 'know how I did this math. Ah, I did this',
#   'start': 2133.04,
#   'duration': 3.84},
#  {'text': 'math assuming this was 47. But this',
#   'start': 2135.2,
#   'duration': 3.6},
#  {'text': "wasn't 47. This was 46 that I bought it",
#   'start': 2136.88,
#   'duration': 4.32},
#  {'text': 'for. I actually would have made 356.',
#   'start': 2138.8,
#   'duration': 4.0},
#  {'text': 'That means my net profit would have been',
#   'start': 2141.2,
#   'duration': 3.28},
#  {'text': 'some $12.', 'start': 2142.8, 'duration': 4.319},
#  {'text': 'I repeat, if Hyderabad would have won on',
#   'start': 2144.48,
#   'duration': 4.96},
#  {'text': 'a capital of $350, I would have made',
#   'start': 2147.119,
#   'duration': 4.96},
#  {'text': '$12. Might sounds insignificant like a',
#   'start': 2149.44,
#   'duration': 4.639},
#  {'text': 'really small number, but I can always I',
#   'start': 2152.079,
#   'duration': 4.241},
#  {'text': 'can always make the numbers bigger,',
#   'start': 2154.079,
#   'duration': 3.681},
#  {'text': 'right? I can always bet more money here,',
#   'start': 2156.32,
#   'duration': 3.519},
#  {'text': 'buy more quantities. As long as the ARB',
#   'start': 2157.76,
#   'duration': 4.56},
#  {'text': 'exists, the ARB will stop to exist at',
#   'start': 2159.839,
#   'duration': 6.24},
#  {'text': 'some point. If you were buying $47 or 47',
#   'start': 2162.32,
#   'duration': 6.12},
#  {'text': 'cents per here, you could at max spend',
#   'start': 2166.079,
#   'duration': 4.561},
#  {'text': '$390 about the price would have gone up',
#   'start': 2168.44,
#   'duration': 4.12},
#  {'text': "to 48. Then the AR wouldn't have",
#   'start': 2170.64,
#   'duration': 4.24},
#  {'text': 'existed. The ARB only exists for a',
#   'start': 2172.56,
#   'duration': 3.76},
#  {'text': 'certain price. There are only certain',
#   'start': 2174.88,
#   'duration': 3.76},
#  {'text': 'quantities that you can buy. In my case,',
#   'start': 2176.32,
#   'duration': 4.799},
#  {'text': 'I bought 250 quantities for 47 first.',
#   'start': 2178.64,
#   'duration': 5.6},
#  {'text': '106 quantities for 46 then. So if',
#   'start': 2181.119,
#   'duration': 5.361},
#  {'text': 'Hyderabad won, I would have made 356. I',
#   'start': 2184.24,
#   'duration': 4.0},
#  {'text': 'assumed this to be 47, hence the number',
#   'start': 2186.48,
#   'duration': 3.599},
#  {'text': 'is smaller. I would have made $12.',
#   'start': 2188.24,
#   'duration': 4.08},
#  {'text': 'Assume this was 47. The market the AR',
#   'start': 2190.079,
#   'duration': 4.121},
#  {'text': "wasn't as big. Still, I would have made",
#   'start': 2192.32,
#   'duration': 5.039},
#  {'text': '$9. Now I was doing a bunch of',
#   'start': 2194.2,
#   'duration': 4.919},
#  {'text': 'calculator opening a calculator on',
#   'start': 2197.359,
#   'duration': 4.161},
#  {'text': 'Google and figuring out what quantities',
#   'start': 2199.119,
#   'duration': 4.641},
#  {'text': 'I should buy. This needs to be very',
#   'start': 2201.52,
#   'duration': 5.28},
#  {'text': "precise because there's just a 1% ar",
#   'start': 2203.76,
#   'duration': 5.44},
#  {'text': 'even 1% less you buy over here. If the',
#   'start': 2206.8,
#   'duration': 3.92},
#  {'text': 'number of quantities are not same on the',
#   'start': 2209.2,
#   'duration': 3.44},
#  {'text': 'other side then you know your ar goes',
#   'start': 2210.72,
#   'duration': 3.92},
#  {'text': 'away. So you have to be very precise and',
#   'start': 2212.64,
#   'duration': 3.92},
#  {'text': 'make sure the final quantities bought on',
#   'start': 2214.64,
#   'duration': 4.0},
#  {'text': 'both the sides are the same. Hence',
#   'start': 2216.56,
#   'duration': 3.76},
#  {'text': 'irrespective of which team wins you make',
#   'start': 2218.64,
#   'duration': 3.68},
#  {'text': 'the same amount which is a little bit',
#   'start': 2220.32,
#   'duration': 3.92},
#  {'text': 'more than what you invested. That was',
#   'start': 2222.32,
#   'duration': 4.24},
#  {'text': 'not true over here. Over here I made a',
#   'start': 2224.24,
#   'duration': 4.64},
#  {'text': 'humongous profit. Not humongous but like',
#   'start': 2226.56,
#   'duration': 3.84},
#  {'text': 'a big profit compared to what I should',
#   'start': 2228.88,
#   'duration': 3.36},
#  ...]

# %% [markdown]
# # Text Splitter

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size = 1000, chunk_overlap = 200)
chunks = splitter.create_documents([transcript])

# %%
len(chunks)
# Out:
# 167

# %%
chunks[0]
# Out:
# Document(metadata={}, page_content='Hi everyone and welcome to a new video. This one is around trading arbitragees in sports book. Um that exists for markets like IPL trading. Um basically it\'s not closer to a MPL or a dream 11. Those are some markets to trade on you know sports opinions in India. Um this is not that um there are other markets that exist where people can trade on the final outcome of the match. Is the match going to win? Is Kolkata going to win? Is Kolkata going to lose? Um when you do that uh you are taking some risk. If you say Kolkata is going to win and Kolkata loses, you lose all of your money. You could bet 100 rupees, a 1,000 rupees or a lakh. Um but is there a way to make risk-free money from these markets? Um you might say, "No, that sounds too good to be true." Um or that sounds like a fatty scheme. Um but if you heard of HFTs, that\'s traditionally what they\'ve been doing for years. Um they are squeezing out inefficiencies from markets without taking any risk themselves. There is some level of')

# %%
embeddings = OllamaEmbeddings(
    model="mistral",
)
vector_store = FAISS.from_documents(chunks, embeddings)

# %%
vector_store.index_to_docstore_id
# Out:
# {0: '7e7bcc98-bf95-4dba-adb8-783eb02e784d',
#  1: '9c2772f7-a9c5-40f7-9510-3708a9d699c1',
#  2: '1dd785d7-8eeb-4d08-a689-e7948cfabcb5',
#  3: 'f033e777-f85b-48a6-94f0-baf36b7c8de6',
#  4: 'e7931c92-e8e3-4c3c-9870-886f818671ed',
#  5: 'c69c266b-b2ad-4238-b4cd-19a4fb54af77',
#  6: 'e457d2e0-3f52-40b6-9294-ad8ffc2c6b56',
#  7: '2a0ca562-268c-4193-8cc3-cee9add1c82c',
#  8: '51b3866a-670a-43de-b8fa-81767b8e38d6',
#  9: '36080cb2-12a0-43ad-a1be-33510dddcbb7',
#  10: 'c9d141cb-4dfd-4362-adfa-4655cdb6c4a4',
#  11: '758029c6-fac3-49c5-9917-43e802534572',
#  12: '32201b22-6331-429b-a8bf-928bca4c7468',
#  13: 'c93104f6-4007-4ba9-8522-9e95dce9b64d',
#  14: 'd37c9cf4-cfce-4cc2-a48f-776a0a8e1d1d',
#  15: '3744af71-3334-4450-ba70-fa908f0ccbe6',
#  16: '04370e2f-fb12-46a5-abe0-a27891e47aaf',
#  17: 'add2b6b7-20b3-4017-a208-f0581fc53736',
#  18: 'aea553cf-decc-40f4-b82e-521a5526daad',
#  19: '461070ab-ba70-4045-93ae-bc7507c63212',
#  20: '6c22dc7d-c8f0-435d-abfd-3d8bc25b2781',
#  21: '35f6a8ed-3484-4502-8667-ef3d934f2fe0',
#  22: '470a2d11-c5f3-407d-a3ec-bbb228dfd8b9',
#  23: 'e6b245c3-d34e-498e-923c-4ce34cc6c517',
#  24: '7ad8022c-2c4c-4c93-a045-d9a1e79bdc7d',
#  25: '1dc37ec5-36f9-4918-a5c5-44bc3f854e58',
#  26: '11e5cedf-76ca-4852-a928-811e51aaa16b',
#  27: 'd1e5348c-fc2a-43fb-9ade-f604a5c7adc5',
#  28: 'bf063d62-25d4-4edb-9782-f18d9cb6aae7',
#  29: 'ed7cea05-6478-4218-a769-d1fa7d20ea42',
#  30: '2d625f53-cf79-422a-b27a-7a03f92b1c70',
#  31: '31ab808f-2f8f-401f-a7ea-b2bec57783c1',
#  32: 'e43312e3-c396-4c0c-b10b-d211817e2de5',
#  33: '83500ba6-1ec2-4541-8f6a-a51ab1d52f81',
#  34: '35ff1774-cc75-4eda-afeb-e68f55bb7550',
#  35: '7c3a6ae9-fb30-40df-8f42-82ee908d7649',
#  36: 'bd7a176b-bbff-48c3-a674-629f42b18bbf',
#  37: 'ac97d40d-d703-4054-b7f1-941486cbba74',
#  38: '6eabf668-26a1-4326-9b83-eb9a7ab5a938',
#  39: 'e942dd3e-c714-4862-9607-584609ac45b1',
#  40: 'ecb78974-0fae-4080-b566-fc19c2cae5d1',
#  41: 'faf55886-6c85-4087-b606-4efc90d22aa4',
#  42: 'fe88035f-9124-440b-ba45-fa4b01c11b1e',
#  43: 'd6925510-5d77-447c-a397-9bcd0867ad7d',
#  44: '7408a90a-ed0e-49d6-a237-7376f0e7bb9d',
#  45: '2e373c8a-b948-4382-a98b-42392c7f1fba',
#  46: '131294b2-131b-48f0-97f6-4e6293524ba0',
#  47: 'bace9c3e-e440-4859-b580-cd7b04265697',
#  48: '78fd6f21-9622-4c0b-980c-51dad8115716',
#  49: 'f556ff56-b3ed-41c0-b64d-3009cd421afc',
#  50: 'aaf2e61c-5049-4d21-b9a1-a58938432bdb',
#  51: 'a3896c06-d826-4717-a52f-9195d77cae12',
#  52: '0dd794b5-ac63-4eb0-8c0f-203bc97c1ab0',
#  53: '6e6d3ab6-65c2-436e-a027-a432430d6315',
#  54: '9d1e4645-22d2-4ebb-ad15-86271aad5af2',
#  55: '7ebbe73c-8b2b-4307-8ef3-d9583b5c60bc',
#  56: 'ba295fd3-d54d-42cf-afdb-6d179e8d9d09',
#  57: '2906cb01-7734-4142-8a4d-8f6254685f3d',
#  58: 'afbebd8f-af98-47a7-b14d-fa1623ae5e0e',
#  59: 'a234e5d5-35fe-494f-86e5-ac7d2f3053ab',
#  60: '9661fbc4-b095-46f7-895e-3ef1230d6496',
#  61: '27be6e30-b5d4-4c45-801c-ac4aafa90c1b',
#  62: '0eeb7d6e-5ae4-4c1f-814e-5acf56a62887',
#  63: 'e6637936-7e95-4627-a7db-57277a13c459',
#  64: 'c7ac879f-18d2-488f-a3c2-199d22b523ff',
#  65: 'a59a71d2-cdb6-4b55-ade0-8af81128fa17',
#  66: 'a1db2852-6ab2-41c1-8a35-ad4bb50c33c9',
#  67: '53bcb322-7c0a-4538-955a-065b2ed7af23',
#  68: '8dac1c3f-bab9-451a-910b-cb86ac0c39e7',
#  69: 'c0c4afe6-3578-4fc5-8468-5d438f7ca354',
#  70: '939bfd0a-19fa-4d66-80e5-e61e72da44cd',
#  71: 'c5118d66-ed8e-446a-90d8-da98dd4d3d0a',
#  72: 'c4c43211-1d04-465b-9b67-7db00ebcc668',
#  73: '8af003dd-4fc5-4185-9ead-0523ea598de6',
#  74: 'dc054ba5-0559-4ec1-94d4-80488225cf40',
#  75: 'c48edf5d-aa08-4b41-a2e2-65410f5a1a95',
#  76: '3684abff-118f-49ac-bd0c-f8920fdfb779',
#  77: 'df332608-f544-4503-9fd3-ed1852f5ba5a',
#  78: 'ec5e86a9-494f-4663-9210-2cf47078cdd4',
#  79: 'abec5ecf-1e1f-4f47-965d-f16798a66b0e',
#  80: 'aaffad99-f43b-4d09-8692-eb0347dd2f05',
#  81: '1fdf6579-e2a0-4da0-967e-e3bcfa7aab21',
#  82: '15a4034f-728c-43e2-9f56-c068439cce84',
#  83: '11d2cb9e-d819-42a6-8a9e-10f63e42dd9a',
#  84: '285b59af-0f94-41aa-85cb-0af21a3cb62e',
#  85: '102a33dc-2201-4f1d-9c29-ada37adae707',
#  86: 'd9f421de-e111-40b3-899d-122e51aba1fb',
#  87: 'c1131d5d-7c98-4238-860e-269dc5f4267f',
#  88: 'f18c8258-05f9-43d2-a58a-c225f453bfb4',
#  89: '66f9f040-3984-4a60-b2e4-58b0d8fe8e0c',
#  90: 'b692616b-afdf-4e2d-b749-f30aee5582ec',
#  91: '48e3dce6-5619-47bf-b012-a94463072bdc',
#  92: '97d76cb5-ef89-488d-8abf-a8e2b85a9423',
#  93: '73d1c06e-25dc-4665-af9a-e9dc7a22f26f',
#  94: '2f2a660d-ca85-439d-b7f4-08f73c3217eb',
#  95: '9d1f40a3-9297-4c97-989d-834aa2db3065',
#  96: '44d51198-f40a-4e19-b780-ba9337045f78',
#  97: '3a104e5b-a7bb-4e26-bd7b-1a44cc92420d',
#  98: 'cb17cec1-a511-458f-a24e-eb1ac55868d9',
#  99: 'f7ca00d7-d342-4871-9c7a-6335472c98e6',
#  100: '930dc4f2-0950-47cf-8695-c1291ed839eb',
#  101: '8b6beffb-b177-4fad-851a-b46d9c2fde95',
#  102: '8c2a4a50-6b24-4c2f-a8ba-e92d94e59600',
#  103: '57a8ad24-d63f-4ada-b100-7f045726f67b',
#  104: '54e45c59-d07b-4024-9733-4db52dc772da',
#  105: 'd9c58815-c57e-4a71-b1b3-9ee8c3a97760',
#  106: 'afd4fcd0-19d7-49fc-ab16-bdcaf355031d',
#  107: '64a33374-112f-44d2-addc-3557fa4a9781',
#  108: '80aad8b4-fe06-418c-9596-ce8ba2bd28b9',
#  109: '25fc7d20-6fe8-4759-a70b-919c4ab2ffa4',
#  110: 'ac05f3b9-5043-4e0d-a8f1-146c5aebfd58',
#  111: 'ed4620a1-3bf0-48b8-b450-0a6b03e57325',
#  112: '3dfea597-12aa-46f2-97fb-e770b2987740',
#  113: '3c153751-adfc-4569-9480-84c4d561402a',
#  114: 'e49da7da-670e-4732-8d5a-812a8b68eb63',
#  115: '887dab39-8305-44f2-995d-fc3886943e8c',
#  116: 'e62a87f4-5322-4f1d-bdba-b409729870d5',
#  117: '32ed32f0-0cbb-4067-99b8-9531940cf05c',
#  118: '1bf1bcfc-b329-4127-8f65-9b924fb2b0ec',
#  119: '01cc5899-435f-45ff-b1f6-b170c0be98c1',
#  120: '707a7852-d022-4c0f-8787-1881183392a8',
#  121: 'b93df9f3-e343-4347-b2f3-639689cb894d',
#  122: '75a16320-6fd5-44f6-b8a1-c7833933301e',
#  123: 'f55170d4-602b-41ea-a1c9-cc57a4289f92',
#  124: '9fe8f15e-f336-42bf-b39d-4ed8d7cf21ee',
#  125: '63a45afc-72f6-4164-9b92-e7bf4e6a64ea',
#  126: '1ab0e5ef-bd1d-42ee-90eb-e5a59511ec88',
#  127: '547a8c77-c0cc-4c2a-9345-f1947f2b05b7',
#  128: 'dad89961-1c55-457b-a8dd-2e0f151256c1',
#  129: '8f086be8-f2ca-4701-9bfe-4f6341c7d98f',
#  130: '14262f41-4bff-4b4d-9e81-6f084429ab16',
#  131: '30529e4e-7109-4c29-afe3-387ff2883b1c',
#  132: '18a0fc2a-0069-4576-9a4c-311a931ff0c3',
#  133: '3beb220a-d9a0-45d0-bc97-d99bf33a164c',
#  134: '383af1d9-1d18-42f2-892f-d294a8ba202c',
#  135: 'f965c3bb-b7c5-41d4-8cfe-03a383d10199',
#  136: '0dd5669a-0279-4a85-9e92-4bc681dd96d5',
#  137: '4728bf83-73ae-4b38-9894-b57f6866a5c9',
#  138: '07c1c40e-db10-4fb6-ba5a-9255335c9d7d',
#  139: 'c07bf9d6-c294-4f86-8a76-965305ffcf4e',
#  140: '4bbbe6ad-8dbc-4f83-97d4-92a4dcfc9f09',
#  141: '80f23704-0a7d-45dd-9696-c809a3aee690',
#  142: '65c98863-5d55-4024-8362-7564ddc112f2',
#  143: '831fc7ed-80ad-4655-825d-a552586233c4',
#  144: '18db10d8-face-4702-874e-03072bb74ad4',
#  145: 'ac2b3b28-2e98-42d6-95a7-c8ed5a6949ed',
#  146: '64718642-9743-49a0-9cdc-1eb26c299c37',
#  147: '34bed2bc-9324-4a05-9186-e16927cc05d2',
#  148: '76c3b115-8e0a-47af-9afb-cbf36e98941e',
#  149: '99c5e202-acad-4c90-9e72-5ff0ffc60898',
#  150: '9eac919e-faf5-4cb6-bf23-99fb24f9d967',
#  151: '53c563dd-923f-4040-bf70-8b19e4e73a19',
#  152: '407f0502-3fb9-4057-be9c-add3ce380a6a',
#  153: 'a3f4b213-e6de-434c-9099-ff396b889ffc',
#  154: '82410fa5-c1be-4ffe-91f0-17c1b1a448c7',
#  155: 'aba7672c-d8f5-435a-bf09-a2d4c3d5b12f',
#  156: 'b875303b-7f29-43c0-8422-9b21ea04a1ce',
#  157: '6a3750a0-835b-4734-bf73-031cdab40c3c',
#  158: '0e958d66-352f-4eca-bfb6-6ae1652bfe33',
#  159: '9e98898d-a7f4-4a9c-b6a6-e1903cb5b41d',
#  160: '68f9eccb-f3a7-4c03-b4b6-70c338aeb22f',
#  161: 'd0cdf7f2-a6c9-4bd1-963b-8653665b08b7',
#  162: '25513872-d22b-44ca-8386-301b9e47d531',
#  163: 'b6627223-5e38-449f-98d9-1d92904e464a',
#  164: '20552625-13ca-4489-9be2-69fa42d5d96a',
#  165: '7b6c983e-e4b7-41d1-b0ba-a35f287bb096',
#  166: '7f9b25cd-63d1-4648-a9d3-b851a966855a'}

# %% [markdown]
# # Retrieval

# %%
retriever = vector_store.as_retriever(search_type="similarity", search_kwargs={"k":4})

# %%
retriever
# Out:
# VectorStoreRetriever(tags=['FAISS', 'OllamaEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x00000197E79363C0>, search_kwargs={'k': 4})

# %%
retriever.invoke("Is this chrome extension locally installed?")
# Out:
# [Document(id='cb17cec1-a511-458f-a24e-eb1ac55868d9', metadata={}, page_content="and five. Um, I'm able to place an order over here. Why can't I place the same order over here? 735. I'm trying to buy. Um, create order. Token ID. Create order. Options. Nope. User order. Token ID, price, size, side. Uh, yeah, I don't see anything wrong there. Let's try it one more time. Uh, not enough balance or allowance. Uh I am able to place the order from here. Do I need to allow my APIs my APIs to have some allowance uh on this account or something like that? That's my guess. Um or I'm just not signing the message correctly. Um that's the other guess. It's probably no that shouldn't be the case. I say I was able to get derive the private key the API keys. Um so the serer object is correct. I would assume that's my last guess that the signer object is incorrect. The Ethereum private key should be in a different format and not a string. Um that's my guess. That's the only thing that that might be wrong. Um because actually I can just Google this error as well. U poly [Music]"),
#  Document(id='8c2a4a50-6b24-4c2f-a8ba-e92d94e59600', metadata={}, page_content="the if you look at the main function you get the user's wallet you get the chain which in our case will be the polygon chain. um we don't need a bunch of these contracts. you only need the USDC contract because we're not using a custom token to you know um to uh over here in poly market I'm not using a custom token I'm using USDC um and hence I don't have to worry about the custom token here just the USDC contract and you can call USDC do approve u to approve a certain amount which in our case is you know I don't know where the amount is sent oh there you go basically all of our USDC balance I am allowing for a specific speific contract um to be able to debit. This is what this lines of code does. If you've ever done ERC20 generally um if you look at ERC20 uh solidity code you'll find um in the ERC20 spec or even if you look at the contract there's an allowance function uh ERC20 create [Music] XRC20 spec [Music] There is expected to be an approve function and an allowance function."),
#  Document(id='aea553cf-decc-40f4-b82e-521a5526daad', metadata={}, page_content="there's a lot of people management involved market makers make money in both of these cases I am the market maker why am I the market maker because I'm making the market the market was illquid before I came this guy was sitting no one was taking his bet this guy was sitting no one was taking his bet I came and I made the market I sat on both the tables beats and I was able to squeeze the inefficiency out of this. Um, this relies on the assumption that traders are not aware of all the markets assumption. Okay, these guys don't can't talk to each other directly. If they could talk to each other, they would of course negotiate a better deal amongst themselves. Since they weren't, I had just the extra knowledge of two tables existing. I sat on both of them, made some money in the middle. Cool. But of course, you don't want to do this offline. Hence, you will do this online. So before we get into doing this online, it's very easy to understand how offline um you know betting would work."),
#  Document(id='78fd6f21-9622-4c0b-980c-51dad8115716', metadata={}, page_content="I should have bought a little bit more of these stocks. That way, this profit should have also been $3 or $4. This profit should also would have been $3 or $4. Since I bought the wrong quantities on both the exchanges and there is only a 1% ARB that exists, even if you miss the quantities a little bit, on one side, you'll make more profit. It went from $6 to $9. On the other side, there was no profit. there was actually loss um that would have happened in case Delhi won at least in my head I had done the math right so I was hoping for a great outcome by the end of the day and imagine what happened I came back home the match is running I open the markets and the markets are extremely liquid they have very big spreads on poly market I if I have a screenshot you'll see it right here and there is a very big price difference between probo and this guy and my math is right in my head so I start to place orders I place an order over I'm trying to place an order on Probo. It's not happening.")]

# %% [markdown]
# # Augmentation

# %%
llm = ChatOllama(model="mistral", temperature=0.2)

# %%
prompt = PromptTemplate(
    template="""
    You are a helpful assistant.
    Answer only from the provided transcript context.
    If the context is insufficient, just say you don't know.
    
    {context}
    question: {question}
    """,
    input_variables=['context', 'question']
)

# %%
question = "is the bot working locally? If yes tell me the basic steps taken to create it."
retrived_docs = retriever.invoke(question)

# %%
context_text = "\n\n".join(doc.page_content for doc in retrived_docs)

# %%
final_prompt = prompt.invoke({"context":context_text, "question":question})

# %% [markdown]
# # Generation

# %%
answer = llm.invoke(final_prompt)
print(answer.content)
# Out:
#  The bot is being developed locally, and here are the basic steps taken to create it:
#
# 1. Set up a development environment for Solidity ( Ethereum's programming language) and Truffle Suite (a popular development framework for Ethereum).
#
# 2. Write the smart contract code using Solidity. In this case, the contract is for managing USDC on the Polygon chain. The contract includes functions like `approve` to allow a specific contract to debit from the user's wallet.
#
# 3. Compile and deploy the contract to the local Ethereum network (e.g., Ganache) using Truffle.
#
# 4. Implement the frontend for interacting with the smart contract, which includes placing orders and managing the market. This is typically done using a web3.js library or a React-based frontend.
#
# 5. Integrate APIs to fetch market data and manage user accounts if needed.
#
# 6. Test the bot locally to ensure it works as expected before deploying it to the mainnet or testnet.

# %% [markdown]
# # Chains

# %%
from langchain_core.runnables import RunnableParallel, RunnablePassthrough, RunnableLambda
from langchain_core.output_parsers import StrOutputParser

# %%
def format_docs(docs):
    context_text = "\n\n".join(doc.page_content for doc in retrived_docs)
    return context_text

# %%
parallel_chain = RunnableParallel({
    'context': retriever | RunnableLambda(format_docs),
    'question': RunnablePassthrough()
})

# %%
parallel_chain.invoke('What is video all about ?')
# Out:
# {'context': "the if you look at the main function you get the user's wallet you get the chain which in our case will be the polygon chain. um we don't need a bunch of these contracts. you only need the USDC contract because we're not using a custom token to you know um to uh over here in poly market I'm not using a custom token I'm using USDC um and hence I don't have to worry about the custom token here just the USDC contract and you can call USDC do approve u to approve a certain amount which in our case is you know I don't know where the amount is sent oh there you go basically all of our USDC balance I am allowing for a specific speific contract um to be able to debit. This is what this lines of code does. If you've ever done ERC20 generally um if you look at ERC20 uh solidity code you'll find um in the ERC20 spec or even if you look at the contract there's an allowance function uh ERC20 create [Music] XRC20 spec [Music] There is expected to be an approve function and an allowance function.\n\nthere's a lot of people management involved market makers make money in both of these cases I am the market maker why am I the market maker because I'm making the market the market was illquid before I came this guy was sitting no one was taking his bet this guy was sitting no one was taking his bet I came and I made the market I sat on both the tables beats and I was able to squeeze the inefficiency out of this. Um, this relies on the assumption that traders are not aware of all the markets assumption. Okay, these guys don't can't talk to each other directly. If they could talk to each other, they would of course negotiate a better deal amongst themselves. Since they weren't, I had just the extra knowledge of two tables existing. I sat on both of them, made some money in the middle. Cool. But of course, you don't want to do this offline. Hence, you will do this online. So before we get into doing this online, it's very easy to understand how offline um you know betting would work.\n\nwill be an array. Uh will it be an array? Something like this. Uh can we make it better? No, I think this is fine. Um do you understand this type? It's basically means uh the depth is going to be it's going to have two things. The buy side and the sell side. Um and the buy side will be a bunch of key value pairs. Uh at 0.5 these many are available. At 47 cents these many are available. At 50 cents these many are available. So on and so forth. You you have the buy side and the sell side. U and this is the exact format in which we need to return things. Also they're in decimals from time to time. So let's make this a let's make this a string string combo. Um let's not use numbers at all. U because we do get decimals. You don't want to deal with decimals um generally u when it comes to you know code. So let's go back over here. We need to change the type of the get depth function to return a promise of depth. It should not return um something random. It should return a promise of depth.\n\nand five. Um, I'm able to place an order over here. Why can't I place the same order over here? 735. I'm trying to buy. Um, create order. Token ID. Create order. Options. Nope. User order. Token ID, price, size, side. Uh, yeah, I don't see anything wrong there. Let's try it one more time. Uh, not enough balance or allowance. Uh I am able to place the order from here. Do I need to allow my APIs my APIs to have some allowance uh on this account or something like that? That's my guess. Um or I'm just not signing the message correctly. Um that's the other guess. It's probably no that shouldn't be the case. I say I was able to get derive the private key the API keys. Um so the serer object is correct. I would assume that's my last guess that the signer object is incorrect. The Ethereum private key should be in a different format and not a string. Um that's my guess. That's the only thing that that might be wrong. Um because actually I can just Google this error as well. U pol ...
#  'question': 'What is video all about ?'}

# %%
parser = StrOutputParser()

# %%
main_chain = parallel_chain | prompt | llm | parser

# %%
main_chain.invoke("Can you tell me a quick summary?")
# Out:
# ' The user is discussing a system where they act as a market maker in a Polygon chain-based market using USDC. They need to approve the contract for a specific amount, which is their entire USDC balance. The system involves an array structure for buy and sell orders, with each side being a series of key-value pairs representing the quantity available at different prices. There seems to be an issue with placing the same order in two places, possibly due to insufficient balance or allowance, or incorrect signing of messages. The user suspects that the signer object might be incorrect and should be in a different format from a string.'
